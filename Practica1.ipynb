# %% [markdown]
# <a href="https://colab.research.google.com/github/MomoHezz/Notas-de-Probabilidad/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

moneda_lados = ["aguila", "sol"]

def lanzar_moneda():
    return random.choice(moneda_lados)

# %%
lanzar_moneda()

# %%
import random

caras_dado = ["1", "2","3","4","5","6"]

def lanzar_dado():
    return random.choice(caras_dado)

# %%
lanzar_dado()
# Out:
# '1'
