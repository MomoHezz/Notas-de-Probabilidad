# %% [markdown]
# <a href="https://colab.research.google.com/github/MomoHezz/Notas-de-Probabilidad/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experimentos

# %% [markdown]
# ## Experimento Determinista

# %% [markdown]
# Un experimento determinista es aquel que produce siempre el mismo resultado cuando se repite bajo las mismas condiciones iniciales.

# %% [markdown]
# Por ejemplo, en matemáticas, si evaluamos la operación 2+3, el resultado siempre será 5. De manera similar, si calculamos el área de un círculo usando la fórmula
#
# A=π⋅r2
#
# y el radio r permanece constante, el resultado del cálculo será siempre el mismo.

# %%
import sympy

def area(radio):
    return sympy.pi * (radio ** 2)

# %% [markdown]
# ## Experimento aleatorio

# %% [markdown]
# En contraste, un experimento aleatorio es aquel que, aún cuando se repita bajo las mismas condiciones, no produce siempre el mismo resultado y no es posible predecir con certeza cuál ocurrirá.

# %% [markdown]
# Por ejemplo, al lanzar una moneda al aire no podemos saber con seguridad si el resultado será cara o cruz antes de observarlo.

# %%
import random

moneda_lados = ["aguila", "sol"]

def lanzar_moneda():
    return random.choice(moneda_lados)

# %%
lanzar_moneda()

# %% [markdown]
# Experimento de lanzar un dado

# %%
import random

caras_dado = ["1", "2","3","4","5","6"]

def lanzar_dado():
    return random.choice(caras_dado)

# %%
lanzar_dado()
# Out:
# '1'
